# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_html('Trade_Map_-_List_of_exporters_for_the_selected_product_in_2022_(Iron_and_steel).xls')
df=df[2]
df.columns=df.iloc[1,:]
df=df.iloc[2:,:]
df=df.set_index('Exporters')
df['Exports in 2022']=[float(i) for i in df.iloc[:,0]]
iron=df['Exports in 2022']
iron=iron.sort_values(ascending=False)
iron
# Out:
# Exporters
# World                        564547394.0
# China                         77264814.0
# Germany                       37031237.0
# Japan                         35162139.0
# Korea, Republic of            28108456.0
#                                 ...
# Guinea-Bissau                        3.0
# Saint Pierre and Miquelon            2.0
# Niue                                 2.0
# Bermuda                              2.0
# Norfolk Island                       1.0
# Name: Exports in 2022, Length: 222, dtype: float64

# %% [markdown]
# # GDP

# %%
dfg=pd.read_excel("API_NY.GDP.MKTP.CD_DS2_en_excel_v2_5795872.xls")
dfg.columns=dfg.iloc[2,:]
dfg=dfg.set_index('Country Name')
dfg.head()
# Out:
# 2                                   Country Code     Indicator Name  \
# Country Name
# Last Updated Date            2023-07-25 00:00:00                NaN
# NaN                                          NaN                NaN
# Country Name                        Country Code     Indicator Name
# Aruba                                        ABW  GDP (current US$)
# Africa Eastern and Southern                  AFE  GDP (current US$)
#
# 2                            Indicator Code        1960.0        1961.0  \
# Country Name
# Last Updated Date                       NaN           NaN           NaN
# NaN                                     NaN           NaN           NaN
# Country Name                 Indicator Code  1.960000e+03  1.961000e+03
# Aruba                        NY.GDP.MKTP.CD           NaN           NaN
# Africa Eastern and Southern  NY.GDP.MKTP.CD  2.112502e+10  2.161623e+10
#
# 2                                  1962.0        1963.0        1964.0  \
# Country Name
# ...

# %%
dfg1=dfg.transpose().iloc[3:,3:]
dfg1['Year']=[int(i) for i in dfg1.index]
dfg1=dfg1.set_index('Year')
dfg1.columns=list(dfg1.columns)
dfg1.head()
# Out:
#      Aruba Africa Eastern and Southern       Afghanistan  \
# Year
# 1960   NaN           21125015452.19735  537777811.111111
# 1961   NaN           21616228139.03751  548888895.555556
# 1962   NaN           23506279899.96653  546666677.777778
# 1963   NaN          28048360188.278782  751111191.111111
# 1964   NaN          25920665259.890041  800000044.444444
#
#      Africa Western and Central Angola Albania Andorra Arab World  \
# Year
# 1960         10447637852.918215    NaN     NaN     NaN        NaN
# 1961         11173212080.394047    NaN     NaN     NaN        NaN
# 1962         11990534017.872967    NaN     NaN     NaN        NaN
# 1963         12727688165.450535    NaN     NaN     NaN        NaN
# 1964         13898109284.017984    NaN     NaN     NaN        NaN
#
#      United Arab Emirates           Argentina  ... Virgin Islands (U.S.)  \
# Year                                           ...
# 1960                  NaN                 NaN  ...                   NaN
# ...

# %%
gdp=dfg1.transpose()
gdp=gdp[2022]
gdp
# Out:
# Aruba                                           NaN
# Africa Eastern and Southern    1169483734191.459229
# Afghanistan                                     NaN
# Africa Western and Central      877863284874.067627
# Angola                           106713618735.43364
#                                        ...
# Kosovo                            9429156201.958513
# Yemen, Rep.                                     NaN
# South Africa                     405869718462.34259
# Zambia                           29784454055.939106
# Zimbabwe                         20678055597.734528
# Name: 2022, Length: 266, dtype: object

# %%
y=list();z=list();g=list();ex=list()
for p in gdp.index:
    for i in list(iron.index):
        if p==i:
            y.append(p)
            z.append(i) 
            g.append(gdp[p])
            ex.append(iron[i]*1000)      # convert thousand USD to Current USD

dnew=pd.DataFrame([y,z,g,ex]).transpose().iloc[:167,:]
dnew.columns=['Country_gdp','Country_iron','GDP','Exports of Iron & Steel']

# %%
# Verify if merging is well done
dnew[dnew['Country_gdp']=='China'],(gdp['China'],iron['China'])
# Out:
# (   Country_gdp Country_iron                    GDP Exports of Iron & Steel
#  31       China        China  17963170521079.832031           77264814000.0,
#  (17963170521079.832, 77264814.0))

# %%
dnew=dnew.sort_values('Exports of Iron & Steel',ascending=False)
dnew=dnew.iloc[-166:,:]             # remove Total related to "World"
dnew.head(20)
# Out:
#             Country_gdp        Country_iron                    GDP  \
# 31                China               China  17963170521079.832031
# 39              Germany             Germany   4072191736089.509766
# 80                Japan               Japan   4231141201863.173828
# 71            Indonesia           Indonesia   1319100220389.018066
# 12              Belgium             Belgium    578604103123.348511
# 130  Russian Federation  Russian Federation   2240422438363.273926
# 77                Italy               Italy   2010431598465.377441
# 52               France              France   2782905325624.524414
# 22               Brazil              Brazil    1920095560995.05957
# 112         Netherlands         Netherlands    991114635529.186768
# 72                India               India   3385089881935.393555
# 47                Spain               Spain   1397509272054.480225
# 28               Canada              Canada   2139840023673.811035
# ...

# %%
import matplotlib.pyplot as plt
fig=plt.subplot()
plt.scatter(x=list(dnew.GDP)[0:50],y=list(dnew['Exports of Iron & Steel'])[0:50])
plt.show()

# %%
dnew1=dnew.iloc[-31:,:]             # remove Total related to "China"
import matplotlib.pyplot as plt
fig=plt.subplot()
plt.scatter(x=list(dnew1.GDP)[0:50],y=list(dnew1['Exports of Iron & Steel'])[0:50])
plt.show()

# %%
iron1.index[1]
# Out:
# 'United Kingdom'

# %%
len('Top 20 Exporters of Iron and Steel in 2022')
# Out:
# 42

# %%
iron1=iron.sort_values(ascending=True)
iron1=iron1[0:(len(iron1)-1)]
iron1=iron1[-20::]
fig=plt.subplot()
plt.barh(iron1.index,iron1.values/1000000)
plt.title('Top 20 Exporters of Iron and Steel in 2022')
plt.ylabel('Countries')
plt.xlabel('Millions of USD')
for i in range(len(iron1)):
    plt.text(y=iron1.index[i],x=(iron1.values[i]/1000000)+0.25,s=str(round(iron1.values[i]/1000000,1)),color='black')
# plt.text(x=iron1.index,y=iron1.values,s=iron1.values,color='black')
fig.axes.get_xaxis().set_ticks([])
plt.text(x=-6,y=-5,s='Source: Realized by Raulin L. Cadet, with data from TradeMap.')
fig.spines[['right', 'top','bottom']].set_visible(False) 
plt.xticks(visible=False)
# Out:
# (array([], dtype=float64), [])

# %%
df
# Out:
# 1                         Value exported in 2022 (USD thousand)  \
# Exporters
# World                                                 564547394
# China                                                  77264814
# Germany                                                37031237
# Japan                                                  35162139
# Korea, Republic of                                     28108456
# ...                                                         ...
# Guinea-Bissau                                                 3
# Saint Pierre and Miquelon                                     2
# Niue                                                          2
# Bermuda                                                       2
# Norfolk Island                                                1
#
# 1                         Trade balance in 2022 (USD thousand)  \
# Exporters
# World                                                -15844797
# ...

# %%
ir
